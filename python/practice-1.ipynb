# %%
a = 5
b = 5

print(id(a) == id(b))
# Out:
# True

# %%
a = 8099531318
b = 8099531318

print(id(a))
print(id(b))
print(id(a) == id(b))
# Out:
# 4633550128
# 4633550192
# False

# %%
a = "Riyaz"
b = "Riyaz"

print(id(a))
print(id(b))

print(id(a) == id(b))
# Out:
# 4633579744
# 4633579744
# True

# %%
a = """
x = 10

print(id(x))

# x + 1 creates a NEW integer object.
x = x + 1

print(id(x))
"""

b = """
x = 10

print(id(x))

# x + 1 creates a NEW integer object.
x = x + 1

print(id(x))
"""

print(id(a))
print(id(b))

print(id(a) == id(b))
# Out:
# 4514494768
# 4514959408
# False
